# %% [markdown]
# >## **Curso de Computación Gráfica**
# >**Universidad Central - Departamento de Ingeniería de Sistemas 2020**
#
#
# > Docente: Miguel Barrero
#
# >Álgebra Lineal
#
# > Estudiante 1: Rojas Alvarado Luis Enrique
#
# > Estudiante 2: Velosa Lozano Carolina
#
#
# >---
#
#
# >1. El espacio vectorial en dos dimensiones es el conjunto de todos los pares ordenados $<x, y>$ de números reales llamados vectores.
# Dado un vector $\vec{PQ}$ que pertenece al espacio bidimensional y que tiene los puntos ${P(-3,5)}$ y ${Q(14,-9)}$ cree un vector $\vec{u}$, que tenga la dirección cotraria dirección de $\vec{PQ}$.

# %%
import numpy as np
p=np.array([-3,5])
q=np.array([14,-9])
print(p,q)
u=np.subtract(q,p)*-1
print('El valor del vector u=',u)
# Out:
# [-3  5] [14 -9]
# El valor del vector u= [-17  14]

# %% [markdown]
# > 2. Escriba una función que permita crear un vector correspondiente para cualquier vector posición. Imprima el vector posición de entrada y el vector correspondiente. Use valores aleatorios para el punto de origen del vector correspondiente.

# %%
import numpy as np

#Función que crea un vector correspondiente dado un vector posición
#Recibe: un  punto.
#Regresa: nada, imprime el vector correspondiente
def creaVectroCorrespondiente(punto):
  #Definimos el vector pos
  valor1=int(input('Ingrese el primer componente del vector posición: '))
  valor2=int(input('Ingrese el primer componente del vector posición: '))
  vpos=np.array([valor1,valor2])
  #sumamos
  res=np.add(vpos,punto)

  #imprimimos la lista    
  print('El vector posicion de entrada: ',vpos)
  print('El vector correspondiente es: ',res)

#####################################
#Se crea un valor aleatorio para el punto de origen:
punto=np.array([np.random.randint(-100,100),np.random.randint(-100,100)])
print('El punto generado es P',punto)
#Se llama a la función con el punto generado
creaVectroCorrespondiente(punto)
# Out:
# El punto generado es P [ -8 -29]
# Ingrese el primer componente del vector posición: 2
# Ingrese el primer componente del vector posición: 5
# El vector posicion de entrada:  [2 5]
# El vector correspondiente es:  [ -6 -24]

# %% [markdown]
# >3. Encuentre un vector unitario *u* para un vector $\vec{pq}$ que parte de los puntos ${P(-3,5)}$ y ${Q(4,-9)}$. Imprima el vector resultante.

# %%
import numpy as np
#Se declaran los puntos P y Q.
P=np.array([-3,5])
Q=np.array([4,-9])
#Se saca el vector posición
VP=np.array(np.subtract(Q,P))
#Se saca la magnitud del vector posición
normalVP=np.sqrt(pow(VP[0],2)+pow(VP[1],2))
#Formula del vector unitario (1/normalVP)*VP
U=1/(normalVP)
u=np.multiply(U,VP)
#Se imprime el vector resultante
print('El vector resultante es: ',u)
# Out:
# El vector resultante es:  [ 0.4472136  -0.89442719]

# %% [markdown]
# >4. Grafique los puntos $P$ y $Q$ del punto 3, el vector correspondiente y el vector posición. Los puntos $P$ y $Q$ deben ser representados de diferente color.

# %%
import matplotlib.pyplot as plt
#graficar los puntos P y Q del punto anterior
#plt.plot(P,Q)
plt.scatter(P,Q,c='y')
plt.text(P[0],P[1],'P',color='R')
plt.text(Q[0],Q[1],'Q',color='R')

#Graficando el Vector posición
# El metodo quiver pinta vectores, pero para que salgan de las
# dimensiones correctas hay que usar los parámetros angles, scale y scale_units
plt.quiver(VP[0], VP[1], angles='xy', scale_units='xy', scale=1)
plt.scatter(VP[0],VP[1],c='m')
plt.text(VP[0],VP[1],'Vp',color='r')
#Vector correspondiente
z=np.array([np.random.randint(-5,5),np.random.randint(-5,5)])
VC=(z)+VP
plt.scatter(VC[0],VC[1])
plt.scatter(z[0],z[1])
plt.quiver(z[0],z[1],VP[0],VP[1],angles='xy',scale_units='xy',scale=1)
plt.text(z[0],z[1],'A')
plt.text(VC[0],VC[1],'VC')
#Definición de gráfico 
plt.title('Grafica punto 4.',color='r')
plt.grid(True)
plt.axvline(0,0,color='black')
plt.axhline(0,0,color='black')
plt.xlim(-5,20)
plt.ylim(-20,10)
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# > 5. En un espacio coordenado de tres dimensiones $(x, y, z)$, calcule la distancia entre $P (3, 5, 7)$ y $Q(-2,3,5)$. Grafique el vector y los dos puntos.

# %%
from mpl_toolkits.mplot3d import axes3d

#Declarar vectores
P5=[3,5,7]
Q5=[-2,3,5]
#Calculando la distancia entre los puntos
RP=np.subtract(Q5,P5)
dist=np.sqrt(pow(RP[0],2)+pow(RP[1],2)+pow(RP[2],2))
print('la distancia entre los puntos es: ',dist)
 
# Creamos la figura
fig = plt.figure(figsize=(14,14))

# Agrrgamos un plano 3D
ax = fig.add_subplot(projection='3d')

#Graficamos los puntos
ax.scatter(P5[0],P5[1],P5[2],c='b')
ax.scatter(Q5[0],Q5[1],Q5[2],c='r')

ax.quiver(P5[0],P5[1],P5[2],RP[0],RP[1],RP[2], length=dist,normalize=True)

# Definicion de grafico
ax.set_xlim3d(-10,10)
ax.set_ylim3d(-10,10)
ax.set_zlim3d(-10,10)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()
# Out:
# la distancia entre los puntos es:  5.744562646538029

# %% [markdown]
# >6. Sean  $a = <2,2,1>$ y $b = <2,1,4>$ las componentes de un par de vectores. Encuentre $2a + 2b$ , $3a-3b$ y $||a||$.

# %%
#Declarando las componentes
a=np.array([2,2,1])
b=np.array([2,1,4])
#Encontrar 2a + 2b
comba1=np.multiply(a,2)
combb1=np.multiply(b,2)
r1=np.add(comba1,combb1)
print('2a+2b=',r1[0],'i',r1[1],'j',r1[2],'k')
#Encontrar 3a-3b
comba2=np.multiply(a,3)
combb2=np.multiply(b,3)
r2=np.subtract(comba1,combb1)
print('3a-3b=',r2[0],'i',r2[1],'j',r2[2],'k')
#Encontrar ||a||
print('||a|| = ',np.sqrt(pow(a[0],2)+pow(a[1],2)+pow(a[2],2)))
# Out:
# 2a+2b= 8 i 6 j 10 k
# 3a-3b= 0 i 2 j -6 k
# ||a|| =  3.0

# %% [markdown]
# >7. Defina una función que le permita calcular el producto escalar del segmento dirigido $a = <5,4,-3>$ y $b = <3,-3,1>$ y el ángulo entre los dos dos vectores. La función debe devolver los dos valores. Imprimalos por pantalla y grafique los vectores.

# %%
import math

#Funcion que permite calcular el producto escalar de dos vectores definidos previamente y el ángulo entre ellos
#Recibe: 2 vectores a y b
#devuelve: el ángulo entre los 2 vectores y un escalar calculado dentro de la función
def prodEsc (a,b):
  #producto punto
  ab=np.multiply(a,b)
  rab=ab[0]+ab[1]+ab[2]
  #Sacando la magnitud de los dos vectores
  normala=np.sqrt(pow(a[0],2)+pow(a[1],2)+pow(a[2],2))
  normalb=np.sqrt(pow(b[0],2)+pow(b[1],2)+pow(b[2],2))
  #se saca el ángulo
  angulo=math.degrees(np.arccos(rab/(normala*normalb)))
  #Regresa los valores
  return angulo, rab, normala, normalb

#Se definen los vectores a y b
a7=np.array([5,4,-3])
b7=np.array([3,-3,1])

#Llamamos a la función que calcula el producto escalar
anguloG, prodesc, dista, distb=prodEsc(a7,b7)
print('El producto escalar es: ',prodesc)
print('El angulo en grados es:',anguloG)

#graficando los vectores

# Creamos la figura
fig2 = plt.figure(figsize=(10,10))

# Agrrgamos un plano 3D
ax2 = fig2.add_subplot(projection='3d')

#Graficamos los puntos
ax2.scatter(a7[0],a7[1],a7[2],c='b')
ax2.scatter(b7[0],b7[1],b7[2],c='r')

ax2.quiver(0,0,0,a7[0],a7[1],a7[2], color='r',length=dista,normalize=True)
ax2.quiver(0,0,0,b7[0],b7[1],b7[2], color='m',length=distb,normalize=True)

# Definicion de grafico
ax2.set_xlim3d(-10,10)
ax2.set_ylim3d(-10,10)
ax2.set_zlim3d(-10,10)

ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('z')

plt.show()
# Out:
# El producto escalar es:  0
# El angulo en grados es: 90.0

# %% [markdown]
# >8. Construya una función que calcule el el producto vectorial entre los vectores $u = <2,-1, 6>$ y $v = <-3,5,1>$. Expreselos en términos de $i, j, k$. Grafique los vectores.

# %%
#Función que calcula el producto vectorial
#Recibe:2 vectores u y v
#Devuelve: nada
def prodVec(u,v):
  #Producto cruz de los 2 vectores
  cruz=np.cross(u,v)
  print('El producto cruz es: ',cruz[0],'i',cruz[1],'j',cruz[2],'k')
  return cruz

#Se definen los vectores
u=np.array([2,-1,6])
v=np.array([-3,5,1])

#Se hace la llamada a función
cruz = prodVec(u,v)
#Se grafica
normalc=np.sqrt(pow(cruz[0],2)+pow(cruz[1],2)+pow(cruz[2],2))
normalu=np.sqrt(pow(u[0],2)+pow(u[1],2)+pow(u[2],2))
normalv=np.sqrt(pow(v[0],2)+pow(v[1],2)+pow(v[2],2))
# Creamos la figura
fig3 = plt.figure(figsize=(10,10))

# Agrrgamos un plano 3D
ax3 = fig3.add_subplot(projection='3d')

#Graficamos los puntos
ax3.scatter(u[0],u[1],u[2],c='b')
ax3.scatter(v[0],v[1],v[2],c='r')
ax3.scatter(cruz[0],cruz[1],cruz[2],c='m')

ax3.quiver(0,0,0,u[0],u[1],u[2], color='r',length=normalu,normalize=True)
ax3.quiver(0,0,0,v[0],v[1],v[2], color='m',length=normalv,normalize=True)
ax3.quiver(0,0,0,cruz[0],cruz[1],cruz[2], color='m',length=normalc,normalize=True)
# Definicion de grafico
ax3.set_xlim3d(-40,10)
ax3.set_ylim3d(-40,10)
ax3.set_zlim3d(-40,10)

ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')

plt.show()
# Out:
# El producto cruz es:  -31 i -20 j 7 k

# %% [markdown]
# >9. Encuentre las ecuaciones paramétricas para la recta $r$ que pasa por $P(2, -2,3)$ y es paralea a $v = <1 ,2,-3>$.
#
# >>1.   Grafique el punto $P$ y la recta $r$.
# >>2.   Grafique el punto en el cual la recta $r$ corta el plano $xy$.
# >>3.   Grafique el vector posición $v$.

# %%
#Encontrar las ecuaciones peramétricas de la recta
#Se definen el punto y el vector
P9=np.array([2,-2,3])
v9=np.array([1,2,-3])

print('La ecuación de la recta es: ')
print(P9[0],'+',v9[0],'t')
print(P9[1],'+',v9[1],'t')
print(P9[2],'+',v9[2],'t')

#Cuando la recta corta el plano xy entonces z=0
print('t=1 porque cuando corta el plano xy, z=0 y despejamos')
z1=0
t=1
print('Por lo que el punto cuando la recta corta el plano xy es: ')
x1=P9[0]+v9[0]*t
y1=P9[1]+v9[1]*t
print('x=',x1)
print('y=',y1)
print('z=',z1)
I=np.array([x1,y1,z1])
print('El punto de intersección es: ', I)
#Graficando

# Creamos la figura
fig6 = plt.figure(figsize=(10,10))

# Agrrgamos un plano 3D
ax6 = fig6.add_subplot(projection='3d')

#Graficamos los puntos
ax6.scatter(P9[0],P9[1],P9[2],c='b')
ax6.scatter(v9[0],v9[1],v9[2],c='r')
ax6.scatter(I[0],I[1],I[2],c='m')

# Definicion de grafico
ax6.set_xlim3d(-10,10)
ax6.set_ylim3d(-10,10)
ax6.set_zlim3d(-10,10)

ax6.set_xlabel('x')
ax6.set_ylabel('y')
ax6.set_zlabel('z')

plt.show()
# Out:
# La ecuación de la recta es:
# 2 + 1 t
# -2 + 2 t
# 3 + -3 t
# t=1 porque cuando corta el plano xy, z=0 y despejamos
# Por lo que el punto cuando la recta corta el plano xy es:
# x= 3
# y= 0
# z= 0
# El punto de intersección es:  [3 0 0]

# %% [markdown]
# >10. Dado el punto $P_1(2,2,-2)$ y $P_2(-2,5,9)$ que se encuentran en la recta $l$, encuentre las ecuaciones paramétricas de la recta. Grafique la recta y los puntos $P_1$ y $P_2$.

# %%
#Se definen los puntos de la recta
P1=np.array([2,2,-2])
P2=np.array([-2,5,9])
#Encontrando el vector posicion
vpos10=np.array(np.subtract(P2,P1))

print('La ecuacion de la recta es: ')
print(P1[0],'+',vpos10[0],'t')
print(P1[1],'+',vpos10[1],'t')
print(P1[2],'+',vpos10[2],'t')

# Creamos la figura
fig5 = plt.figure(figsize=(10,10))

# Agrrgamos un plano 3D
ax5 = fig5.add_subplot(projection='3d')

#Graficamos los puntos
ax5.scatter(P1[0],P1[1],P1[2],c='b')
ax5.scatter(P2[0],P2[1],P2[2],c='r')


# Definicion de grafico
ax5.set_xlim3d(-10,10)
ax5.set_ylim3d(-10,10)
ax5.set_zlim3d(-10,10)

ax5.set_xlabel('x')
ax5.set_ylabel('y')
ax5.set_zlabel('z')

plt.show()
# Out:
# La ecuacion de la recta es:
# 2 + -4 t
# 2 + 3 t
# -2 + 11 t
